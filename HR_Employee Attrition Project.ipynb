# %%
# Import the necessary packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('Attrition Case Study.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
# Attrition                   1470 non-null int64
# Age                         1470 non-null int64
# BusinessTravel              1470 non-null object
# DailyRate                   1470 non-null int64
# Department                  1470 non-null object
# DistanceFromHome            1470 non-null int64
# Education                   1470 non-null int64
# EducationField              1470 non-null object
# EmployeeCount               1470 non-null int64
# EmployeeNumber              1470 non-null int64
# EnvironmentSatisfaction     1470 non-null int64
# Gender                      1470 non-null object
# HourlyRate                  1470 non-null int64
# JobInvolvement              1470 non-null int64
# JobLevel                    1470 non-null int64
# JobRole                     1470 non-null object
# JobSatisfaction             1470 non-null int64
# MaritalStatus               1470 non-null object
# MonthlyIncome               1470 non-null int64
# MonthlyRate                 1470 non-null int64
# NumCompaniesWorked          1470 non-null int64
# Over18                      1470 non-null object
# OverTime                    1470 non-null object
# PercentSalaryHike           1470 non-null int64
# PerformanceRating           1470 non-null int64
# RelationshipSatisfaction    1470 non-null int64
# StandardHours               1470 non-null int64
# StockOptionLevel            1470 non-null int64
# TotalWorkingYears           1470 non-null int64
# TrainingTimesLastYear       1470 non-null int64
# WorkLifeBalance             1470 non-null int64
# YearsAtCompany              1470 non-null int64
# YearsInCurrentRole          1470 non-null int64
# YearsSinceLastPromotion     1470 non-null int64
# YearsWithCurrManager        1470 non-null int64
# dtypes: int64(27), object(8)
# memory usage: 356.1+ KB

# %%
print(data.columns)
# Out:
# Index(['Attrition', 'Age', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
print(data.shape)
# Out:
# (1470, 35)

# %%
print(data.describe())
# Out:
#          Attrition          Age    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000  1470.000000       1470.000000  1470.000000
# mean      0.161224    36.923810   802.485714          9.192517     2.912925
# std       0.367863     9.135373   403.509100          8.106864     1.024165
# min       0.000000    18.000000   102.000000          1.000000     1.000000
# 25%       0.000000    30.000000   465.000000          2.000000     2.000000
# 50%       0.000000    36.000000   802.000000          7.000000     3.000000
# 75%       0.000000    43.000000  1157.000000         14.000000     4.000000
# max       1.000000    60.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction   HourlyRate  \
# count         1470.0     1470.000000              1470.000000  1470.000000
# mean             1.0     1024.865306                 2.721769    65.891156
# std              0.0      602.024335                 1.093082    20.329428
# min              1.0        1.000000                 1.000000    30.000000
# 25%              1.0      491.250000                 2.000000    48.000000
# 50%              1.0     1020.500000                 3.000000    66.000000
# 75%              1.0     1555.750000                 4.000000    83.750000
# max              1.0     2068.000000                 4.000000   100.000000
#
#        JobInvolvement          ...           RelationshipSatisfaction  \
# count     1470.000000          ...                        1470.000000
# mean         2.729932          ...                           2.712245
# std          0.711561          ...                           1.081209
# min          1.000000          ...                           1.000000
# 25%          2.000000          ...                           2.000000
# 50%          3.000000          ...                           3.000000
# 75%          3.000000          ...                           4.000000
# max          4.000000          ...                           4.000000
#
#        StandardHours  StockOptionLevel  TotalWorkingYears  \
# count         1470.0       1470.000000        1470.000000
# mean            80.0          0.793878          11.279592
# std              0.0          0.852077           7.780782
# min             80.0          0.000000           0.000000
# 25%             80.0          0.000000           6.000000
# 50%             80.0          1.000000          10.000000
# 75%             80.0          1.000000          15.000000
# max             80.0          3.000000          40.000000
#
#        TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# count            1470.000000      1470.000000     1470.000000
# mean                2.799320         2.761224        7.008163
# std                 1.289271         0.706476        6.126525
# min                 0.000000         1.000000        0.000000
# 25%                 2.000000         2.000000        3.000000
# 50%                 3.000000         3.000000        5.000000
# 75%                 3.000000         3.000000        9.000000
# max                 6.000000         4.000000       40.000000
#
#        YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# count         1470.000000              1470.000000           1470.000000
# mean             4.229252                 2.187755              4.123129
# std              3.623137                 3.222430              3.568136
# min              0.000000                 0.000000              0.000000
# 25%              2.000000                 0.000000              2.000000
# 50%              3.000000                 1.000000              3.000000
# 75%              7.000000                 3.000000              7.000000
# max             18.000000                15.000000             17.000000
#
# [8 rows x 27 columns]

# %%
data = data.sample(frac = 0.1,random_state = 1)
print(data.shape)
# Out:
# (147, 35)

# %%
# plot Histogram of each parameter
data.hist(figsize = (20,20))
plt.show()

# %%
# check if any null value is present
data.isnull().values.any()
# Out:
# False

# %%
## Correlation
#get correlations of each features in dataset
corrmat = data.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(30,30))
#plot heat map
g=sns.heatmap(data[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
data.corr()
# Out:
#                           Attrition       Age  DailyRate  DistanceFromHome  \
# Attrition                  1.000000 -0.298801   0.003588          0.030858
# Age                       -0.298801  1.000000   0.088411         -0.021040
# DailyRate                  0.003588  0.088411   1.000000         -0.038652
# DistanceFromHome           0.030858 -0.021040  -0.038652          1.000000
# Education                 -0.072297  0.276174  -0.054212          0.046008
# EmployeeCount                   NaN       NaN        NaN               NaN
# EmployeeNumber            -0.024644 -0.026177  -0.003171          0.088216
# EnvironmentSatisfaction   -0.233072  0.157204  -0.033921         -0.002892
# HourlyRate                -0.205404  0.109787   0.024855          0.036944
# JobInvolvement            -0.197677  0.075440   0.103040         -0.033418
# JobLevel                  -0.312057  0.515901   0.035254          0.010969
# JobSatisfaction           -0.193818  0.010737   0.007311         -0.050675
# MonthlyIncome             -0.281674  0.519794   0.024879          0.008335
# MonthlyRate                0.183724  0.108733   0.049039          0.045840
# NumCompaniesWorked         0.103317  0.265206   0.099104         -0.018679
# PercentSalaryHike          0.032660  0.005966   0.107696         -0.005980
# PerformanceRating          0.122543 -0.009788   0.065706         -0.026246
# RelationshipSatisfaction  -0.209703  0.039492  -0.066397         -0.022206
# StandardHours                   NaN       NaN        NaN               NaN
# StockOptionLevel          -0.184211  0.135462   0.086576          0.045989
# TotalWorkingYears         -0.283969  0.712712   0.077338         -0.019986
# TrainingTimesLastYear     -0.010323 -0.053501  -0.024168          0.067805
# WorkLifeBalance            0.142316 -0.072010  -0.025043         -0.058331
# YearsAtCompany            -0.234164  0.403000  -0.068194          0.068148
# YearsInCurrentRole        -0.232646  0.330908   0.002166          0.093507
# YearsSinceLastPromotion   -0.238207  0.265194   0.026566          0.022269
# YearsWithCurrManager      -0.216771  0.321145  -0.016582          0.016979
#
#                           Education  EmployeeCount  EmployeeNumber  \
# Attrition                 -0.072297            NaN       -0.024644
# Age                        0.276174            NaN       -0.026177
# DailyRate                 -0.054212            NaN       -0.003171
# DistanceFromHome           0.046008            NaN        0.088216
# Education                  1.000000            NaN        0.260163
# EmployeeCount                   NaN            NaN             NaN
# EmployeeNumber             0.260163            NaN        1.000000
# EnvironmentSatisfaction   -0.004078            NaN        0.007776
# HourlyRate                 0.058982            NaN        0.017321
# JobInvolvement             0.070772            NaN        0.040731
# JobLevel                  -0.007900            NaN       -0.090722
# JobSatisfaction            0.056338            NaN       -0.086702
# MonthlyIncome             -0.030199            NaN       -0.080399
# MonthlyRate                0.070907            NaN        0.012056
# NumCompaniesWorked         0.087085            NaN        0.050805
# PercentSalaryHike          0.024120            NaN       -0.039105
# PerformanceRating          0.041418            NaN       -0.097422
# RelationshipSatisfaction  -0.036293            NaN       -0.084268
# StandardHours                   NaN            NaN             NaN
# StockOptionLevel           0.152805            NaN        0.060755
# TotalWorkingYears          0.115259            NaN       -0.023676
# TrainingTimesLastYear     -0.025088            NaN        0.081766
# WorkLifeBalance           -0.165323            NaN        0.068201
# YearsAtCompany             0.029903            NaN       -0.094649
# YearsInCurrentRole         0.014131            NaN       -0.044351
# YearsSinceLastPromotion   -0.008836            NaN       -0.001811
# YearsWithCurrManager      -0.007442            NaN       -0.074559
#
#                           EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# Attrition                               -0.233072   -0.205404       -0.197677
# Age                                      0.157204    0.109787        0.075440
# DailyRate                               -0.033921    0.024855        0.103040
# DistanceFromHome                        -0.002892    0.036944       -0.033418
# Education                               -0.004078    0.058982        0.070772
# EmployeeCount                                 NaN         NaN             NaN
# EmployeeNumber                           0.007776    0.017321        0.040731
# EnvironmentSatisfaction                  1.000000    0.076679       -0.003788
# HourlyRate                               0.076679    1.000000       -0.027597
# JobInvolvement                          -0.003788   -0.027597        1.000000
# JobLevel                                 0.140504    0.081084       -0.075377
# JobSatisfaction                         -0.067977   -0.106402        0.044453
# MonthlyIncome                            0.166854    0.079491       -0.055825
# MonthlyRate                             -0.037829    0.112675       -0.151244
# NumCompaniesWorked                      -0.084698   -0.118586        0.063464
# PercentSalaryHike                       -0.129845   -0.111032       -0.040074
# PerformanceRating                       -0.132924   -0.148404       -0.004205
# RelationshipSatisfaction                -0.019758   -0.040879        0.052310
# StandardHours                                 NaN         NaN             NaN
# StockOptionLevel                        -0.094582    0.039650        0.155539
# TotalWorkingYears                        0.095092    0.068599       -0.001043
# TrainingTimesLastYear                   -0.049481   -0.176388       -0.032985
# WorkLifeBalance                         -0.007965   -0.155803       -0.090829
# YearsAtCompany                           0.087313    0.027361       -0.065034
# YearsInCurrentRole                       0.104435   -0.018726        0.058138
# YearsSinceLastPromotion                  0.030790    0.017099        0.035555
# YearsWithCurrManager                     0.002562    0.021995        0.030682
#
#                                   ...           RelationshipSatisfaction  \
# Attrition                         ...                      -2.097034e-01
# Age                               ...                       3.949219e-02
# DailyRate                         ...                      -6.639714e-02
# DistanceFromHome                  ...                      -2.220561e-02
# Education                         ...                      -3.629302e-02
# EmployeeCount                     ...                                NaN
# EmployeeNumber                    ...                      -8.426807e-02
# EnvironmentSatisfaction           ...                      -1.975846e-02
# HourlyRate                        ...                      -4.087877e-02
# JobInvolvement                    ...                       5.231049e-02
# JobLevel                          ...                       6.110283e-02
# JobSatisfaction                   ...                       3.395569e-02
# MonthlyIncome                     ...                       8.042045e-02
# MonthlyRate                       ...                      -4.300902e-02
# NumCompaniesWorked                ...                       7.927348e-02
# PercentSalaryHike                 ...                       2.205234e-03
# PerformanceRating                 ...                       8.122496e-19
# RelationshipSatisfaction          ...                       1.000000e+00
# StandardHours                     ...                                NaN
# StockOptionLevel                  ...                       2.800485e-02
# TotalWorkingYears                 ...                       5.311663e-02
# TrainingTimesLastYear             ...                      -7.125271e-03
# WorkLifeBalance                   ...                       6.228505e-02
# YearsAtCompany                    ...                      -7.140561e-03
# YearsInCurrentRole                ...                      -1.039824e-02
# YearsSinceLastPromotion           ...                       1.500924e-01
# YearsWithCurrManager              ...                      -1.740166e-02
#
#                           StandardHours  StockOptionLevel  TotalWorkingYears  \
# Attrition                           NaN         -0.184211          -0.283969
# Age                                 NaN          0.135462           0.712712
# DailyRate                           NaN          0.086576           0.077338
# DistanceFromHome                    NaN          0.045989          -0.019986
# Education                           NaN          0.152805           0.115259
# EmployeeCount                       NaN               NaN                NaN
# EmployeeNumber                      NaN          0.060755          -0.023676
# EnvironmentSatisfaction             NaN         -0.094582           0.095092
# HourlyRate                          NaN          0.039650           0.068599
# JobInvolvement                      NaN          0.155539          -0.001043
# JobLevel                            NaN          0.026380           0.805596
# JobSatisfaction                     NaN          0.047606          -0.068254
# MonthlyIncome                       NaN         -0.000573           0.786656
# MonthlyRate                         NaN         -0.195502           0.109120
# NumCompaniesWorked                  NaN          0.141756           0.163117
# PercentSalaryHike                   NaN         -0.008827           0.008423
# PerformanceRating                   NaN         -0.068994           0.053549
# RelationshipSatisfaction            NaN          0.028005           0.053117
# StandardHours                       NaN               NaN                NaN
# StockOptionLevel                    NaN          1.000000           0.101451
# TotalWorkingYears                   NaN          0.101451           1.000000
# TrainingTimesLastYear               NaN          0.085442          -0.019869
# WorkLifeBalance                     NaN          0.017594           0.051157
# YearsAtCompany                      NaN         -0.003579           0.708473
# YearsInCurrentRole                  NaN          0.068210           0.565660
# YearsSinceLastPromotion             NaN          0.060152           0.468955
# YearsWithCurrManager                NaN          0.014761           0.587265
#
#                           TrainingTimesLastYear  WorkLifeBalance  \
# Attrition                             -0.010323         0.142316
# Age                                   -0.053501        -0.072010
# DailyRate                             -0.024168        -0.025043
# DistanceFromHome                       0.067805        -0.058331
# Education                             -0.025088        -0.165323
# EmployeeCount                               NaN              NaN
# EmployeeNumber                         0.081766         0.068201
# EnvironmentSatisfaction               -0.049481        -0.007965
# HourlyRate                            -0.176388        -0.155803
# JobInvolvement                        -0.032985        -0.090829
# JobLevel                               0.037250         0.073960
# JobSatisfaction                        0.106379        -0.082367
# MonthlyIncome                         -0.000388         0.100163
# MonthlyRate                           -0.134258         0.092110
# NumCompaniesWorked                    -0.010164         0.075153
# PercentSalaryHike                     -0.061584        -0.120871
# PerformanceRating                     -0.050128         0.011639
# RelationshipSatisfaction              -0.007125         0.062285
# StandardHours                               NaN              NaN
# StockOptionLevel                       0.085442         0.017594
# TotalWorkingYears                     -0.019869         0.051157
# TrainingTimesLastYear                  1.000000         0.038557
# WorkLifeBalance                        0.038557         1.000000
# YearsAtCompany                         0.077885         0.058670
# YearsInCurrentRole                     0.109535         0.062604
# YearsSinceLastPromotion                0.021526         0.094693
# YearsWithCurrManager                   0.103655         0.074937
#
#                           YearsAtCompany  YearsInCurrentRole  \
# Attrition                      -0.234164           -0.232646
# Age                             0.403000            0.330908
# DailyRate                      -0.068194            0.002166
# DistanceFromHome                0.068148            0.093507
# Education                       0.029903            0.014131
# EmployeeCount                        NaN                 NaN
# EmployeeNumber                 -0.094649           -0.044351
# EnvironmentSatisfaction         0.087313            0.104435
# HourlyRate                      0.027361           -0.018726
# JobInvolvement                 -0.065034            0.058138
# JobLevel                        0.645082            0.540603
# JobSatisfaction                 0.041359            0.144313
# MonthlyIncome                   0.607453            0.501172
# MonthlyRate                     0.054528            0.079213
# NumCompaniesWorked             -0.169155           -0.128775
# PercentSalaryHike              -0.054854            0.006354
# PerformanceRating              -0.047036            0.049954
# RelationshipSatisfaction       -0.007141           -0.010398
# StandardHours                        NaN                 NaN
# StockOptionLevel               -0.003579            0.068210
# TotalWorkingYears               0.708473            0.565660
# TrainingTimesLastYear           0.077885            0.109535
# WorkLifeBalance                 0.058670            0.062604
# YearsAtCompany                  1.000000            0.746163
# YearsInCurrentRole              0.746163            1.000000
# YearsSinceLastPromotion         0.576205            0.589609
# YearsWithCurrManager            0.787456            0.676996
#
#                           YearsSinceLastPromotion  YearsWithCurrManager
# Attrition                               -0.238207             -0.216771
# Age                                      0.265194              0.321145
# DailyRate                                0.026566             -0.016582
# DistanceFromHome                         0.022269              0.016979
# Education                               -0.008836             -0.007442
# EmployeeCount                                 NaN                   NaN
# EmployeeNumber                          -0.001811             -0.074559
# EnvironmentSatisfaction                  0.030790              0.002562
# HourlyRate                               0.017099              0.021995
# JobInvolvement                           0.035555              0.030682
# JobLevel                                 0.506874              0.537250
# JobSatisfaction                          0.054317              0.020019
# MonthlyIncome                            0.488303              0.483212
# MonthlyRate                              0.050691             -0.008351
# NumCompaniesWorked                       0.021923             -0.129374
# PercentSalaryHike                       -0.088198              0.029851
# PerformanceRating                       -0.054595              0.027576
# RelationshipSatisfaction                 0.150092             -0.017402
# StandardHours                                 NaN                   NaN
# StockOptionLevel                         0.060152              0.014761
# TotalWorkingYears                        0.468955              0.587265
# TrainingTimesLastYear                    0.021526              0.103655
# WorkLifeBalance                          0.094693              0.074937
# YearsAtCompany                           0.576205              0.787456
# YearsInCurrentRole                       0.589609              0.676996
# YearsSinceLastPromotion                  1.000000              0.451239
# YearsWithCurrManager                     0.451239              1.000000
#
# [27 rows x 27 columns]

# %%
## Train Test Split

from sklearn.model_selection import train_test_split
feature_columns = ['Age', 'DailyRate',
       'DistanceFromHome',  'EmployeeCount',
       'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate',
       'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating',
       'RelationshipSatisfaction', 'StockOptionLevel',
       'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
       'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
       'YearsWithCurrManager']
predicted_class = ['Attrition']

# %%
X = data[feature_columns].values
y = data[predicted_class].values


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state=10)

# %%
## Apply Algorithm

from sklearn.ensemble import RandomForestClassifier
random_forest_model = RandomForestClassifier(random_state=10)

random_forest_model.fit(X_train, y_train.ravel())
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=10, verbose=0, warm_start=False)

# %%
predict_train_data = random_forest_model.predict(X_test)

from sklearn import metrics

print("Accuracy = {0:.3f}".format(metrics.accuracy_score(y_test, predict_train_data)))
# Out:
# Accuracy = 0.733

# %%
plt.figure()
